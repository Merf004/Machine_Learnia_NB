# %% [markdown]
# ## Analyse dataset Titanic

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_excel('titanic3.xls')

# %%
data
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
data.shape
# Out:
# (1309, 14)

# %%
data.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
# Elimination des colonnes pas utiles

data = data.drop(['name', 'sibsp', 'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'], axis = 1)
data.head()
# Out:
#    pclass  survived     sex      age
# 0       1         1  female  29.0000
# 1       1         1    male   0.9167
# 2       1         0  female   2.0000
# 3       1         0    male  30.0000
# 4       1         0  female  25.0000

# %%
# Statistique de base de toutes les colonnes

data.describe()
# Il manque des données: (1)Soit on remplace par une valeur par defaut(moyenne, mode, ...) ou (2)eliminer les lignes avec valeurs manquantes
# Out:
#             pclass     survived          age
# count  1309.000000  1309.000000  1046.000000
# mean      2.294882     0.381971    29.881135
# std       0.837836     0.486055    14.413500
# min       1.000000     0.000000     0.166700
# 25%       2.000000     0.000000    21.000000
# 50%       3.000000     0.000000    28.000000
# 75%       3.000000     1.000000    39.000000
# max       3.000000     1.000000    80.000000

# %%
# (1)

data1 = data.fillna(data['age'].mean())
data1.describe()
# Out:
#             pclass     survived          age
# count  1309.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135
# std       0.837836     0.486055    12.883199
# min       1.000000     0.000000     0.166700
# 25%       2.000000     0.000000    22.000000
# 50%       3.000000     0.000000    29.881135
# 75%       3.000000     1.000000    35.000000
# max       3.000000     1.000000    80.000000

# %%
# (2)

data2 = data.dropna(axis = 0) # ou data.dropna(axis = 0, inplace = True) Pas besoin de reecrire le nom du dataset avec inplace
data2.describe()
# Out:
#             pclass     survived          age
# count  1046.000000  1046.000000  1046.000000
# mean      2.207457     0.408222    29.881135
# std       0.841497     0.491740    14.413500
# min       1.000000     0.000000     0.166700
# 25%       1.000000     0.000000    21.000000
# 50%       2.000000     0.000000    28.000000
# 75%       3.000000     1.000000    39.000000
# max       3.000000     1.000000    80.000000

# %%
# Nombre de personne en 1ere, 2eme ou 3eme classe

data['pclass'].value_counts()
# Out:
# pclass
# 3    709
# 1    323
# 2    277
# Name: count, dtype: int64

# %%
data['pclass'].value_counts().plot.bar() # ou data['pclass'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='pclass'>

# %%
data['age'].hist()
# Out:
# <Axes: >

# %%
# Analyse en regroupant les gens selon leur sexe

data.groupby(['sex', 'pclass']).mean()
# Out:
#                survived        age
# sex    pclass
# female 1       0.965278  37.037594
#        2       0.886792  27.499191
#        3       0.490741  22.185307
# male   1       0.340782  41.029250
#        2       0.146199  30.815401
#        3       0.152130  25.962273

# %% [markdown]
# ## Series

# %% [markdown]
# Une serie est un tableau numpy à 1D + un axe des index
#
# Un dataframe est considéré comme un dictionnaire qui contient des series. En realité un dictionnaire est une association clé:valeur; un dataframe est une association index:series

# %%
# Possibilité d'indexer le dataset avec une autre colonne que celle des index

d = pd.read_excel('titanic3.xls')
d = d.set_index('name')
d
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Allison, Miss. Helen Loraine                          1         0  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
# ...                                                 ...       ...     ...
# Zabour, Miss. Hileni                                  3         0  female
# Zabour, Miss. Thamine                                 3         0  female
# Zakarian, Mr. Mapriededer                             3         0    male
# Zakarian, Mr. Ortin                                   3         0    male
# Zimmerman, Mr. Leo                                    3         0    male
#
#                                                      age  sibsp  parch  \
# ...

# %%
# Possibilité de faire de l'indexing sutr dataframe

data['age'][0:10]
# Out:
# 0    29.0000
# 1     0.9167
# 2     2.0000
# 3    30.0000
# 4    25.0000
# 5    48.0000
# 6    63.0000
# 7    39.0000
# 8    53.0000
# 9    71.0000
# Name: age, dtype: float64

# %%
# Possibilité de faire du boolean indexing sutr dataframe
data[data['age']<18]['pclass'].value_counts()
# Out:
# pclass
# 3    106
# 2     33
# 1     15
# Name: count, dtype: int64

# %%
data[data['age']<18].groupby(['sex','pclass']).mean()
# Out:
#                survived        age
# sex    pclass
# female 1       0.875000  14.125000
#        2       1.000000   8.273150
#        3       0.543478   8.416667
# male   1       0.857143   9.845243
#        2       0.733333   6.222220
#        3       0.233333   9.838888

# %% [markdown]
# ### Fonction iloc[] et loc[]

# %% [markdown]
# Meme resultat avec iloc et loc

# %%
# Avec iloc on peut faire de l'indexing exactement comme dans Numpy

data.iloc[24:58, 0:2]
# Out:
#     pclass  survived
# 24       1         1
# 25       1         0
# 26       1         1
# 27       1         1
# 28       1         1
# 29       1         1
# 30       1         0
# 31       1         1
# 32       1         1
# 33       1         1
# 34       1         0
# 35       1         1
# 36       1         1
# 37       1         1
# 38       1         0
# 39       1         0
# 40       1         0
# 41       1         1
# 42       1         1
# 43       1         1
# 44       1         1
# 45       1         0
# 46       1         0
# 47       1         1
# 48       1         1
# 49       1         1
# 50       1         1
# 51       1         0
# 52       1         0
# 53       1         0
# 54       1         1
# 55       1         1
# 56       1         1
# 57       1         1

# %%
# La fonction loc permet de faire la meme chose mais en travaillant sur les colonnes

data.loc[24:58, ['pclass', 'survived']]
# Out:
#     pclass  survived
# 24       1         1
# 25       1         0
# 26       1         1
# 27       1         1
# 28       1         1
# 29       1         1
# 30       1         0
# 31       1         1
# 32       1         1
# 33       1         1
# 34       1         0
# 35       1         1
# 36       1         1
# 37       1         1
# 38       1         0
# 39       1         0
# 40       1         0
# 41       1         1
# 42       1         1
# 43       1         1
# 44       1         1
# 45       1         0
# 46       1         0
# 47       1         1
# 48       1         1
# 49       1         1
# 50       1         1
# 51       1         0
# 52       1         0
# 53       1         0
# 54       1         1
# 55       1         1
# 56       1         1
# 57       1         1
# 58       1         0

# %% [markdown]
# ## Pandas et series temporelles

# %% [markdown]
# ### Analyse des données du bitcoin

# %%
bitcoin = pd.read_csv('BTC-EUR.csv', index_col='Date', parse_dates=True)
bitcoin
# index_col = 'Date': Pour mettre en index la colonne des dates
# parse_dates = True: Pour changer les tranformer en date(etant au préalable en str)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2011-10-04     3.700000     3.821000     3.746000     3.750000     3.750000
# 2011-10-05     3.750000     3.820000     3.650000     3.676000     3.676000
# 2011-10-06     3.676000     3.743000     3.450000     3.550000     3.550000
# 2011-10-07     3.550000     3.590000     2.900000     3.293000     3.293000
# 2011-10-08     3.293000     3.283000     2.872000     2.890000     2.890000
# ...                 ...          ...          ...          ...          ...
# 2019-09-30  7375.950195  7667.890137  7075.589844  7626.029785  7626.029785
# 2019-10-01  7626.029785  7818.279785  7535.799805  7625.560059  7625.560059
# 2019-10-02  7625.560059  7663.270020  7489.770020  7655.250000  7655.250000
# 2019-10-03  7655.250000  7685.930176  7379.220215  7516.790039  7516.790039
# 2019-10-04  7514.477051  7512.555176  7424.196289  7487.083496  7487.083496
#
#                  Volume
# Date
# ...

# %%
# Evolution du bitcoin en 2019
bitcoin.loc['2019']['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Evolution du bitcoin en sept 2015
bitcoin.loc['2015-09']['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Fonction resample()

# %% [markdown]
# Elle permet de regrouper les données selon une frequence temporelle

# %%
# Regroupement des données bitcoin en 2019 en moyenne par mois
bitcoin.loc['2019']['Close'].resample('M').mean().plot()

# %%
# Regroupement des données bitcoin en 2019 en moyenne tous les trimestres
bitcoin.loc['2019']['Close'].resample('3M').mean().plot()
# Out:
# /tmp/ipykernel_99559/4290721527.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   bitcoin.loc['2019']['Close'].resample('3M').mean().plot()
# <Axes: xlabel='Date'>

# %%
# Regroupement des données bitcoin en 2017 en moyenne tous les 5 jours
bitcoin.loc['2019']['Close'].resample('5D').mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Fonction aggregate()

# %% [markdown]
# Elle fait la meme chose que resample mais permet d'avoir plusieurs mesures statistiques

# %%
# Regroupement des données bitcoin en 2019 par mois
bitcoin.loc['2019']['Close'].resample('M').agg(['mean', 'std', 'min', 'max'])
# Out:
# /tmp/ipykernel_99559/871703383.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   bitcoin.loc['2019']['Close'].resample('M').agg(['mean', 'std', 'min', 'max'])
#                    mean          std          min           max
# Date
# 2019-01-31  3224.996440   161.596014  2986.850098   3565.800049
# 2019-02-28  3243.951817   182.032761  2973.739990   3648.610107
# 2019-03-31  3488.300348    88.840620  3285.050049   3657.600098
# 2019-04-30  4597.852043   217.844525  3702.659912   4943.890137
# 2019-05-31  6524.075179  1031.720010  4787.600098   7848.660156
# 2019-06-30  8321.163265  1330.243836  6797.279785  11240.339844
# 2019-07-31  9509.937059   785.964673  8406.070313  11225.849609
# 2019-08-31  9558.389680   604.741999  8580.379883  10722.349609
# 2019-09-30  8897.111035   776.796010  7375.950195   9685.990234
# 2019-10-31  7571.170899    81.762757  7487.083496   7655.250000

# %%
# Regroupement des données bitcoin en 2019 par mois
bitcoin.loc['2019']['Close'].resample('M').agg(['mean', 'std', 'min', 'max']).plot()
# Out:
# /tmp/ipykernel_99559/2815923817.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   bitcoin.loc['2019']['Close'].resample('M').agg(['mean', 'std', 'min', 'max']).plot()
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Moyenne mobile

# %% [markdown]
# Faire la moyenne sur une fenetre de valeur, en avance d'une unité dans le graphe. Oun utilise une fonction rolling

# %%
# Creation de la fonction rolling avec une fentre de 7
bitcoin.loc["2019"]['Close'].rolling(window = 7).mean().plot()
# On peut l'utiliser avec d'autre statistique(ecart-type, min, max)
# Out:
# <Axes: xlabel='Date'>

# %%
plt.figure(figsize = (12,8))
bitcoin.loc['2019']['Close'].plot(label = 'Close')
bitcoin.loc["2019"]['Close'].rolling(window = 7).mean().plot(label = 'Moyenne mobile', ls=':')
plt.legend()

# %%
# Parametre center pour centrer le resulata de la moyenne mobile, et non le mettre à la fin

plt.figure(figsize = (12,8))
bitcoin.loc['2019-09']['Close'].plot(label = 'Close')
bitcoin.loc["2019-9"]['Close'].rolling(window = 7, center = True).mean().plot(label = 'Moyenne mobile: center = True', ls=':')
bitcoin.loc["2019-9"]['Close'].rolling(window = 7).mean().plot(label = 'Moyenne mobile: center = False', ls=':')
plt.legend()

# %% [markdown]
# ### Moyenne mobile exponentielle

# %% [markdown]
# Elle suit la formule: MME = alpha(xt + (1 - alpha)xt-1 + (1-alpha)**2xt-2 + (1 - alpha)**3xt-3) + ...)

# %%
plt.figure(figsize = (12,8))
bitcoin.loc['2019-09']['Close'].plot(label = 'Close')
bitcoin.loc["2019-9"]['Close'].rolling(window = 7, center = True).mean().plot(label = 'Moyenne mobile: center = True', ls=':')
bitcoin.loc["2019-9"]['Close'].rolling(window = 7).mean().plot(label = 'Moyenne mobile: center = False', ls=':')
bitcoin.loc["2019-9"]['Close'].ewm(alpha = 0.6).mean().plot(label = 'Moyenne mobile exponentielle', ls=':')
plt.legend()

# %% [markdown]
# ### Assembler des datasets

# %%
ethereum = pd.read_csv('ETH-EUR.csv', index_col='Date', parse_dates=True)
ethereum
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-08-07    0.593000   20.000000    0.593000    2.560000    2.560000
# 2015-08-08    2.560000    2.598000    0.561600    0.650000    0.650000
# 2015-08-09    0.650000    0.800000    0.523500    0.700000    0.700000
# 2015-08-10    0.700000    0.750000    0.585000    0.680000    0.680000
# 2015-08-11    0.680000    1.008000    0.591500    0.950000    0.950000
# ...                ...         ...         ...         ...         ...
# 2019-09-30  155.160004  166.649994  151.229996  165.910004  165.910004
# 2019-10-01  165.910004  170.710007  159.330002  161.410004  161.410004
# 2019-10-02  161.410004  165.740005  159.699997  165.240005  165.240005
# 2019-10-03  165.240005  165.520004  154.960007  159.690002  159.690002
# 2019-10-07  155.179993  166.309998  153.889999  164.929993  164.929993
#
#               Volume
# Date
# 2015-08-07     15200
# 2015-08-08     32816
# 2015-08-09      4041
# ...

# %%
ethereum.loc['2019']['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Assemblage avec inner
btc_eth = pd.merge(bitcoin, ethereum, on='Date', how='inner', suffixes=('_btc', '_eth'))
btc_eth

# Les données bitcoin commencent en 2011 et les données ethereum en 2015. Avec inner, on supprimme toutes les données qui ne sont pas en
# commun. Donc toutes les lignes avec date de bitcoin < 2015
# Out:
#                Open_btc     High_btc      Low_btc    Close_btc  Adj Close_btc  \
# Date
# 2015-08-07   255.710007   258.880005   253.639999   256.250000     256.250000
# 2015-08-08   256.250000   257.029999   239.279999   240.199997     240.199997
# 2015-08-09   240.199997   246.110001   239.039993   243.910004     243.910004
# 2015-08-10   243.910004   248.039993   240.779999   241.679993     241.679993
# 2015-08-11   241.679993   247.190002   240.399994   245.759995     245.759995
# ...                 ...          ...          ...          ...            ...
# 2019-09-29  7523.009766  7541.020020  7247.169922  7375.950195    7375.950195
# 2019-09-30  7375.950195  7667.890137  7075.589844  7626.029785    7626.029785
# 2019-10-01  7626.029785  7818.279785  7535.799805  7625.560059    7625.560059
# 2019-10-02  7625.560059  7663.270020  7489.770020  7655.250000    7655.250000
# 2019-10-03  7655.250000  7685.930176  7379.220215  7516.790039    7516.790039
#
# ...

# %%
# Assemblage avec outer
pd.merge(bitcoin, ethereum, on='Date', how='outer', suffixes=('_btc', '_eth'))

# Avec outer, on assemble toutes les données meme ceux qui ne sont pas en commun et on met des NaN
# Out:
#                Open_btc     High_btc      Low_btc    Close_btc  Adj Close_btc  \
# Date
# 2011-10-04     3.700000     3.821000     3.746000     3.750000       3.750000
# 2011-10-05     3.750000     3.820000     3.650000     3.676000       3.676000
# 2011-10-06     3.676000     3.743000     3.450000     3.550000       3.550000
# 2011-10-07     3.550000     3.590000     2.900000     3.293000       3.293000
# 2011-10-08     3.293000     3.283000     2.872000     2.890000       2.890000
# ...                 ...          ...          ...          ...            ...
# 2019-10-01  7626.029785  7818.279785  7535.799805  7625.560059    7625.560059
# 2019-10-02  7625.560059  7663.270020  7489.770020  7655.250000    7655.250000
# 2019-10-03  7655.250000  7685.930176  7379.220215  7516.790039    7516.790039
# 2019-10-04  7514.477051  7512.555176  7424.196289  7487.083496    7487.083496
# 2019-10-07          NaN          NaN          NaN          NaN            NaN
#
# ...

# %%
btc_eth[['Close_btc', 'Close_eth']].plot(subplots = True, figsize = (12,8))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
# Correlation entre le bitcoin et l'ethereum
btc_eth[['Close_btc', 'Close_eth']].corr()
# Out:
#            Close_btc  Close_eth
# Close_btc   1.000000   0.791416
# Close_eth   0.791416   1.000000
